# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\kukis\Downloads\Py_Tryout\Football_data\Bundesliga_Keeper_Save_Percentagexlsx.xlsx")

df
# Out:
#                   Name  Save Percentage
# 0      Frederik Rønnow             7.91
# 1          Yann Sommer             7.70
# 2      Rafal Gikiewicz             7.57
# 3         Manuel Neuer             7.50
# 4         Mark Flekken             7.38
# 5         Gregor Kobel             7.29
# 6        Koen Casteels             7.26
# 7       Oliver Baumann             6.76
# 8        Jiri Pavlenka             6.53
# 9   Oliver Christensen             6.51
# 10      Manuel Riemann             6.40
# 11      Lukas Hradecky             6.31
# 12      Florian Müller             6.25
# 13  Alexander Schwolow             6.24
# 14       Robin Zentner             6.13

# %%
df.rename(columns = {'Save Percentage':'Save Percentage (%)'}, inplace = True)
df
# Out:
#                   Name  Save Percentage (%)
# 0      Frederik Rønnow                 7.91
# 1          Yann Sommer                 7.70
# 2      Rafal Gikiewicz                 7.57
# 3         Manuel Neuer                 7.50
# 4         Mark Flekken                 7.38
# 5         Gregor Kobel                 7.29
# 6        Koen Casteels                 7.26
# 7       Oliver Baumann                 6.76
# 8        Jiri Pavlenka                 6.53
# 9   Oliver Christensen                 6.51
# 10      Manuel Riemann                 6.40
# 11      Lukas Hradecky                 6.31
# 12      Florian Müller                 6.25
# 13  Alexander Schwolow                 6.24
# 14       Robin Zentner                 6.13

# %%
import plotly
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import plotly.io as pio

pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %%
for template in ['seaborn']:
    fig = px.scatter(df, 
               x = 'Name',
               y = "Save Percentage (%)", 
               color = 'Save Percentage (%)', 
               size = "Save Percentage (%)",
               text = "Save Percentage (%)", height = 650, width = 950,
               template = 'seaborn', 
               title = "<b> Top 15 Keeper Bundesliga 2022/2023 Save Percentage (Aug-Nov) <b>")
    
    
    fig.update_traces(textfont_size=8, textposition='top center')
    fig.show(renderer="svg")
